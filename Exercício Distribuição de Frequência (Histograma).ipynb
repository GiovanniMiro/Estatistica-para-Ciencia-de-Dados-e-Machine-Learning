# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('census.csv')
dataset.shape
# Out:
# (32561, 15)

# %%
dataset['age']
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64

# %%
dataset['age'].count()
# Out:
# 32561

# %%
dataset['age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
dataset['age'].plot.hist();

# %%
sns.histplot(dataset['age'], bins = 10, kde = 'True');

# %%
dataset['age'] = pd.cut(dataset['age'], bins=[0, 17, 25, 40, 60, 90], labels = ['Faixa 1', 'Faixa 2', 'Faixa 3', 'Faixa 4', 'Faixa 5'])

# %%
dataset['age'].head()
# Out:
# 0    Faixa 3
# 1    Faixa 4
# 2    Faixa 3
# 3    Faixa 4
# 4    Faixa 3
# Name: age, dtype: category
# Categories (5, object): ['Faixa 1' < 'Faixa 2' < 'Faixa 3' < 'Faixa 4' < 'Faixa 5']

# %%
dataset['age'].unique()
# Out:
# ['Faixa 3', 'Faixa 4', 'Faixa 2', 'Faixa 5', 'Faixa 1']
# Categories (5, object): ['Faixa 1' < 'Faixa 2' < 'Faixa 3' < 'Faixa 4' < 'Faixa 5']

# %%
sns.histplot(dataset['age']);
